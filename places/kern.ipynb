# %% [markdown]
# ## Configuration
# _Initial steps to get the notebook ready to play nice with our repository. Do not delete this section._

# %% [markdown]
# Code formatting with [black](https://pypi.org/project/nb-black/).

# %%
# %load_ext lab_black

# %%
import os
import pathlib

# %%
this_dir = pathlib.Path(os.path.abspath(""))

# %%
data_dir = this_dir / "data"

# %%
import pytz
import glob
import json
import requests
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## Fetch a valid token

# %%
TOKEN_URL = "https://phweb.kerncounty.com/Geocortex/Essentials/REST/sites/COVID19_PublicInfo?f=json&deep=true"

# %%
response = requests.get(TOKEN_URL)
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_2017/455250294.py in <module>
#       1 response = requests.get(TOKEN_URL)
# ----> 2 data = response.json()
#
# ~/.local/share/virtualenvs/california-coronavirus-scrapers-dxuBXRsm/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# /opt/hostedtoolcache/Python/3.8.14/x64/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /opt/hostedtoolcache/Python/3.8.14/x64/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/hostedtoolcache/Python/3.8.14/x64/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
connectionString = data["map"]["mapServices"][0]["connectionString"]
parts = connectionString.split(";")
token = parts[-1]

# %% [markdown]
# ## Retrieve the feed

# %%
url = f"https://phweb.kerncounty.com/arcgis/rest/services/PH/COVID19_PublicInfo/MapServer/0/query?{token}&f=json&where=1%3D1&returnGeometry=false&outFields=*"

# %%
response = requests.get(url)
data = response.json()

# %% [markdown]
# ## Parse

# %%
dict_list = []

for item in data["features"]:
    po_name = item["attributes"]["PO_NAME"]
    zip_code = item["attributes"]["zipCode"].strip()

    if po_name == "unk":
        po_name = "Unknown"

    if zip_code:
        area = f"{zip_code}: {po_name}"
    else:
        area = po_name

    d = dict(
        county="Kern",
        area=area,
        city=po_name,
        zip_code=zip_code,
        confirmed_cases=item["attributes"]["cnt"],
    )
    dict_list.append(d)

# %% [markdown]
# Convert to dataframe

# %%
df = pd.DataFrame(dict_list)

# %% [markdown]
# #### Get timestamp

# %%
timestamp = data["features"][0]["attributes"]["sysdate"]
timestamp = datetime.fromtimestamp((timestamp / 1000))
latest_date = pd.to_datetime(timestamp).date()

# %%
df["county_date"] = latest_date

# %%
tz = pytz.timezone("America/Los_Angeles")

# %%
today = datetime.now(tz).date()

# %%
slug = "kern"

# %%
export_df = df[["county", "area", "county_date", "confirmed_cases", "zip_code"]]

# %% [markdown]
# ## Vet

# %%
try:
    assert not len(df) > 51
except AssertionError:
    raise AssertionError("Kern's area scraper has extra rows")

# %%
try:
    assert not len(df) < 51
except AssertionError:
    raise AssertionError("Kern's area scraper is missing rows")

# %% [markdown]
# ## Export

# %%
df.to_csv(data_dir / slug / f"{today}.csv", index=False)

# %% [markdown]
# ## Combine

# %%
csv_list = [
    i
    for i in glob.glob(str(data_dir / slug / "*.csv"))
    if not str(i).endswith("timeseries.csv")
]

# %%
df_list = []
for csv in csv_list:
    if "manual" in csv:
        df = pd.read_csv(csv, parse_dates=["date"])
    else:
        file_date = csv.split("/")[-1].replace(".csv", "")
        df = pd.read_csv(csv, parse_dates=["county_date"])
        df["date"] = file_date
    df_list.append(df)

# %%
df = pd.concat(df_list).sort_values(["date", "area"]).drop(["city"], axis=1)

# %%
df.to_csv(data_dir / slug / "timeseries.csv", index=False)
